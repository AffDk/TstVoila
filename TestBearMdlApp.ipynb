# %%
# !pip install -Uqq fastbook 
import fastbook
fastbook.setup_book()


# !: the command won't be run in python but in the shell. U: upgrade qq: means display only the messages with ERROR,CRITICAL log levels

# %%
import os
import pathlib
from fastai.vision.all import *
from fastai.vision.widgets import *

current_path = os.getcwd()

def load_posix_learner(path):
    save = pathlib.PosixPath
    pathlib.PosixPath = pathlib.WindowsPath
    
    learn = load_learner(path)
    
    pathlib.PosixPath = save
    return learn

learn_inf = load_posix_learner((current_path + '\BearNetModel.pkl'))

# %% [markdown]
# Bear Classifier
# **bold text**
#
# This is a simplified classifier based on resent just to classify images of bears into Black, Grizzly and Teddy
#
# upoload your photo and then press classify to the picture into the abovementioned categories
#
# ![BearLogo.jpg](data:image/jpeg;base64,...)

# %%
btn_upload = widgets.FileUpload()
out_pl = widgets.Output()
# out_pl.clear_output()
btn_run = widgets.Button(description='Classify')
lbl_pred = widgets.Label()

def on_click_classify(change):
    img = PILImage.create(btn_upload.data[-1])
    out_pl.clear_output()
    with out_pl: display(img.to_thumb(128,128))
    pred,pred_idx,probs = learn_inf.predict(img)
    lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'

# %%
btn_run.on_click(on_click_classify)
VBox([widgets.Label('Select your bear!'), 
      btn_upload, btn_run, out_pl, lbl_pred])
# Out:
# VBox(children=(Label(value='Select your bear!'), FileUpload(value={}, description='Upload'), Button(descriptio…
# C:\Users\afsamani\AppData\Local\Continuum\anaconda3\lib\site-packages\torch\nn\functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  ..\c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)

# %%
# !pip install voila
# !jupyter serverextension enable --sys-prefix voila
# Out:
# Collecting voila
#   Downloading voila-0.2.10-py3-none-any.whl (1.6 MB)
# Collecting nbclient<0.6,>=0.4.0
#   Using cached nbclient-0.5.3-py3-none-any.whl (82 kB)
# Collecting nbconvert<7,>=6.0.0
#   Downloading nbconvert-6.1.0-py3-none-any.whl (551 kB)
# Collecting jupyter-server<2.0.0,>=0.3.0
#   Downloading jupyter_server-1.9.0-py3-none-any.whl (389 kB)
# Collecting jupyter-client<7,>=6.1.3
#   Using cached jupyter_client-6.1.12-py3-none-any.whl (112 kB)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\afsamani\appdata\local\continuum\anaconda3\lib\site-packages (from jupyter-client<7,>=6.1.3->voila) (2.8.0)
# Collecting jupyter-core>=4.6.0
#   Using cached jupyter_core-4.7.1-py3-none-any.whl (82 kB)
# Requirement already satisfied: tornado>=4.1 in c:\users\afsamani\appdata\local\continuum\anaconda3\lib\site-packages (from jupyter-client<7,>=6.1.3->voila) (6.0.3)
# Requirement already satisfied: traitlets in c:\users\afsamani\appdata\local\continuum\anaconda3\lib\site-packages (from jupyter-client<7,>=6.1.3->voila) (4.3.3)
# Requirement already satisfied: pyzmq>=13 in c:\users\afsamani\appdata\local\continuum\anaconda3\lib\site-packages (from jupyter-client<7,>=6.1.3->voila) (18.1.0)
# Requirement already satisfied: pywin32>=1.0 in c:\users\afsamani\appdata\local\continuum\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<7,>=6.1.3->voila) (223)
# Collecting argon2-cffi
#   Downloading argon2_cffi-20.1.0-cp37-cp37m-win_amd64.whl (42 kB)
# Requirement already satisfied: prometheus-client in c:\users\afsamani\appdata\local\continuum\anaconda3\lib\site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (0.7.1)
# Collecting anyio<4,>=3.1.0
#   Downloading anyio-3.2.1-py3-none-any.whl (75 kB)
# Collecting requests-unixsocket
#   Downloading requests_unixsocket-0.2.0-py2.py3-none-any.whl (11 kB)
# Collecting terminado>=0.8.3
#   Downloading terminado-0.10.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: Send2Trash in c:\users\afsamani\appdata\local\continuum\anaconda3\lib\site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (1.5.0)
# Requirement already satisfied: ipython-genutils in c:\users\afsamani\appdata\local\continuum\anaconda3\lib\site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (0.2.0)
# Requirement already satisfied: jinja2 in c:\users\afsamani\appdata\local\continuum\anaconda3\lib\site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (2.10.3)
# Requirement already satisfied: nbformat in c:\users\afsamani\appdata\local\continuum\anaconda3\lib\site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (4.4.0)
# Collecting tornado>=4.1
#   Downloading tornado-6.1-cp37-cp37m-win_amd64.whl (422 kB)
# Collecting websocket-client
#   Downloading websocket_client-1.1.0-py2.py3-none-any.whl (68 kB)
# Requirement already satisfied: typing-extensions in c:\users\afsamani\appdata\roaming\python\python37\site-packages (from anyio<4,>=3.1.0->jupyter-server<2.0.0,>=0.3.0->voila) (3.7.4.3)
# Requirement already satisfied: idna>=2.8 in c:\users\afsamani\appdata\local\continuum\anaconda3\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server<2.0.0,>=0.3.0->voila) (2.8)
# Collecting sniffio>=1.1
#   Downloading sniffio-1.2.0-py3-none-any.whl (10 kB)
# Collecting nbformat
#   Using cached nbformat-5.1.3-py3-none-any.whl (178 kB)
# Collecting nest-asyncio
#   Using cached nest_asyncio-1.5.1-py3-none-any.whl (5.0 kB)
# Collecting async-generator
#   Using cached async_generator-1.10-py3-none-any.whl (18 kB)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\afsamani\appdata\local\continuum\anaconda3\lib\site-packages (from nbconvert<7,>=6.0.0->voila) (0.8.4)
# Requirement already satisfied: defusedxml in c:\users\afsamani\appdata\local\continuum\anaconda3\lib\site-packages (from nbconvert<7,>=6.0.0->voila) (0.6.0)
# Collecting traitlets
#   Downloading traitlets-5.0.5-py3-none-any.whl (100 kB)
# Requirement already satisfied: bleach in c:\users\afsamani\appdata\local\continuum\anaconda3\lib\site-packages (from nbconvert<7,>=6.0.0->voila) (3.1.0)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\afsamani\appdata\local\continuum\anaconda3\lib\site-packages (from nbconvert<7,>=6.0.0->voila) (2.4.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\afsamani\appdata\local\continuum\anaconda3\lib\site-packages (from nbconvert<7,>=6.0.0->voila) (1.4.2)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\afsamani\appdata\local\continuum\anaconda3\lib\site-packages (from nbconvert<7,>=6.0.0->voila) (0.3)
# Collecting jupyterlab-pygments
#   Using cached jupyterlab_pygments-0.1.2-py2.py3-none-any.whl (4.6 kB)
# Requirement already satisfied: testpath in c:\users\afsamani\appdata\local\continuum\anaconda3\lib\site-packages (from nbconvert<7,>=6.0.0->voila) (0.4.2)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\afsamani\appdata\local\continuum\anaconda3\lib\site-packages (from jinja2->jupyter-server<2.0.0,>=0.3.0->voila) (1.1.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\afsamani\appdata\local\continuum\anaconda3\lib\site-packages (from nbformat->jupyter-server<2.0.0,>=0.3.0->voila) (3.0.2)
# Requirement already satisfied: setuptools in c:\users\afsamani\appdata\local\continuum\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->jupyter-server<2.0.0,>=0.3.0->voila) (41.4.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\afsamani\appdata\local\continuum\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->jupyter-server<2.0.0,>=0.3.0->voila) (0.15.4)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\afsamani\appdata\local\continuum\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->jupyter-server<2.0.0,>=0.3.0->voila) (19.2.0)
# Requirement already satisfied: six>=1.11.0 in c:\users\afsamani\appdata\roaming\python\python37\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->jupyter-server<2.0.0,>=0.3.0->voila) (1.15.0)
# Collecting pywinpty>=1.1.0
#   Downloading pywinpty-1.1.3-cp37-none-win_amd64.whl (1.3 MB)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\afsamani\appdata\local\continuum\anaconda3\lib\site-packages (from argon2-cffi->jupyter-server<2.0.0,>=0.3.0->voila) (1.12.3)
# Requirement already satisfied: pycparser in c:\users\afsamani\appdata\local\continuum\anaconda3\lib\site-packages (from cffi>=1.0.0->argon2-cffi->jupyter-server<2.0.0,>=0.3.0->voila) (2.19)
# Requirement already satisfied: webencodings in c:\users\afsamani\appdata\local\continuum\anaconda3\lib\site-packages (from bleach->nbconvert<7,>=6.0.0->voila) (0.5.1)
# Requirement already satisfied: requests>=1.1 in c:\users\afsamani\appdata\local\continuum\anaconda3\lib\site-packages (from requests-unixsocket->jupyter-server<2.0.0,>=0.3.0->voila) (2.22.0)
# Requirement already satisfied: urllib3>=1.8 in c:\users\afsamani\appdata\local\continuum\anaconda3\lib\site-packages (from requests-unixsocket->jupyter-server<2.0.0,>=0.3.0->voila) (1.24.2)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\afsamani\appdata\local\continuum\anaconda3\lib\site-packages (from requests>=1.1->requests-unixsocket->jupyter-server<2.0.0,>=0.3.0->voila) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\afsamani\appdata\local\continuum\anaconda3\lib\site-packages (from requests>=1.1->requests-unixsocket->jupyter-server<2.0.0,>=0.3.0->voila) (2019.9.11)
# Installing collected packages: traitlets, tornado, jupyter-core, nest-asyncio, nbformat, jupyter-client, async-generator, sniffio, pywinpty, nbclient, jupyterlab-pygments, websocket-client, terminado, requests-unixsocket, nbconvert, argon2-cffi, anyio, jupyter-server, voila
#   Attempting uninstall: traitlets
#     Found existing installation: traitlets 4.3.3
#     Uninstalling traitlets-4.3.3:
#       Successfully uninstalled traitlets-4.3.3
#   Attempting uninstall: tornado
#     Found existing installation: tornado 6.0.3
#     Uninstalling tornado-6.0.3:
#       Successfully uninstalled tornado-6.0.3
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'c:\\users\\afsamani\\appdata\\local\\continuum\\anaconda3\\lib\\site-packages\\~ornado\\speedups.cp37-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.
#
# WARNING: You are using pip version 21.0; however, version 21.1.3 is available.
# You should consider upgrading via the 'c:\users\afsamani\appdata\local\continuum\anaconda3\pythonw.exe -m pip install --upgrade pip' command.
# Enabling: voila
# - Writing config: C:\Users\afsamani\AppData\Local\Continuum\anaconda3\etc\jupyter
#     - Validating...
# Error loading server extension voila
#       X is voila importable?
